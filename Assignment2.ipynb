# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student_loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/mbc/ai/m6/datasets/student_loans.csv"
data = pd.read_csv(file_path)

# Review the DataFrame
data.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               5
# 1                  9.8               5
# 2                  9.8               5
# 3                  9.8               6
# 4                  9.4               5

# %%
# Review the data types associated with the columns
print(data.dtypes)
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = data["credit_ranking"]

# Display a sample of y
y.sample(n=20)
# Out:
# 1564    5
# 1299    3
# 88      5
# 154     5
# 1430    5
# 830     4
# 461     5
# 888     6
# 1205    7
# 140     5
# 442     7
# 1224    6
# 570     6
# 1295    5
# 548     6
# 207     5
# 1369    4
# 1141    6
# 329     5
# 835     5
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = data.copy().drop(columns="credit_ranking")

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score
# 0                  9.4
# 1                  9.8
# 2                  9.8
# 3                  9.8
# 4                  9.4

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
standard_scalar = StandardScaler()

# Fit the scaler to the features training dataset
standard_scalar.fit(X_train)

# Fit the scaler to the features training dataset
X_train_scaled = standard_scalar.transform(X_train)
X_test_scaled = standard_scalar.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
input_features = 11

# Review the number of features
input_features
# Out:
# 11

# %%
# Define the number of neurons in the output layer
output_neurons = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_firstlayer = 6

# Review the number hidden nodes in the first layer
hidden_nodes_firstlayer

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes_secondlayer = 4

# Review the number hidden nodes in the second layer
hidden_nodes_secondlayer
# Out:
# 4

# %%
# Create the Sequential model instance
nn = Sequential()

# %%
# Add the first hidden layer
nn.add(Dense(units = hidden_nodes_firstlayer, input_dim = input_features, activation = "relu"))

# %%
# Add the second hidden layer
nn.add(Dense(units = hidden_nodes_secondlayer, activation = "relu"))

# %%
# Add the output layer to the model specifying the number of output neurons and activation function
nn.add(Dense(units = output_neurons, activation = "linear"))

# %%
# Display the Sequential model summary
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 6)                 72
#
#  dense_10 (Dense)            (None, 6)                 42
#
#  dense_11 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 121 (484.00 Byte)
# Trainable params: 121 (484.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `mse` loss function, the `adam` optimizer, and the `mse` evaluation metric.

# %%
# Compile the Sequential model
nn.compile(loss = "mean_squared_error", optimizer = "adam", metrics = ["mse"])

# %%
# Fit the model using 50 epochs and the training data
model_1 = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 2ms/step - loss: 28.7466 - mse: 28.7466
# Epoch 2/50
# 38/38 [==============================] - 0s 2ms/step - loss: 23.8751 - mse: 23.8751
# Epoch 3/50
# 38/38 [==============================] - 0s 2ms/step - loss: 19.0683 - mse: 19.0683
# Epoch 4/50
# 38/38 [==============================] - 0s 2ms/step - loss: 14.7092 - mse: 14.7092
# Epoch 5/50
# 38/38 [==============================] - 0s 2ms/step - loss: 11.1123 - mse: 11.1123
# Epoch 6/50
# 38/38 [==============================] - 0s 2ms/step - loss: 8.3567 - mse: 8.3567
# Epoch 7/50
# 38/38 [==============================] - 0s 2ms/step - loss: 6.3268 - mse: 6.3268
# Epoch 8/50
# 38/38 [==============================] - 0s 2ms/step - loss: 4.9311 - mse: 4.9311
# Epoch 9/50
# 38/38 [==============================] - 0s 2ms/step - loss: 3.9635 - mse: 3.9635
# Epoch 10/50
# 38/38 [==============================] - 0s 2ms/step - loss: 3.2928 - mse: 3.2928
# Epoch 11/50
# 38/38 [==============================] - 0s 2ms/step - loss: 2.8445 - mse: 2.8445
# Epoch 12/50
# 38/38 [==============================] - 0s 2ms/step - loss: 2.5237 - mse: 2.5237
# Epoch 13/50
# 38/38 [==============================] - 0s 2ms/step - loss: 2.2850 - mse: 2.2850
# Epoch 14/50
# 38/38 [==============================] - 0s 2ms/step - loss: 2.1024 - mse: 2.1024
# Epoch 15/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.9447 - mse: 1.9447
# Epoch 16/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8150 - mse: 1.8150
# Epoch 17/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.6979 - mse: 1.6979
# Epoch 18/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5939 - mse: 1.5939
# Epoch 19/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5062 - mse: 1.5062
# Epoch 20/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.4258 - mse: 1.4258
# Epoch 21/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.3571 - mse: 1.3571
# Epoch 22/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2963 - mse: 1.2963
# Epoch 23/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2433 - mse: 1.2433
# Epoch 24/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1950 - mse: 1.1950
# Epoch 25/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1535 - mse: 1.1535
# Epoch 26/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1076 - mse: 1.1076
# Epoch 27/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0681 - mse: 1.0681
# Epoch 28/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0317 - mse: 1.0317
# Epoch 29/50
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0002 - mse: 1.0002
# Epoch 30/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.9669 - mse: 0.9669
# Epoch 31/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9392 - mse: 0.9392
# Epoch 32/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.9096 - mse: 0.9096
# Epoch 33/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.8825 - mse: 0.8825
# Epoch 34/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.8578 - mse: 0.8578
# Epoch 35/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.8369 - mse: 0.8369
# Epoch 36/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.8129 - mse: 0.8129
# Epoch 37/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7944 - mse: 0.7944
# Epoch 38/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7754 - mse: 0.7754
# Epoch 39/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7559 - mse: 0.7559
# Epoch 40/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7397 - mse: 0.7397
# Epoch 41/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7235 - mse: 0.7235
# Epoch 42/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7089 - mse: 0.7089
# Epoch 43/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6941 - mse: 0.6941
# Epoch 44/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6821 - mse: 0.6821
# Epoch 45/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6668 - mse: 0.6668
# Epoch 46/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6550 - mse: 0.6550
# Epoch 47/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6408 - mse: 0.6408
# Epoch 48/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6315 - mse: 0.6315
# Epoch 49/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6189 - mse: 0.6189
# Epoch 50/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6084 - mse: 0.6084

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 13/13 - 0s - loss: 0.6240 - mse: 0.6240 - 34ms/epoch - 3ms/step
# Loss: 0.6240339279174805, Accuracy: 0.6240339279174805

# %% [markdown]
# ### Step 4: Save and export your model to an HDF5 file, and name the file `student_loans.h5`.

# %%
# Set the model's file path
file_path = Path("models/loans.h5")

# Export your model to a HDF5 file
nn.save(file_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path = Path("models/loans.h5")

# Load the model to a new object
nn_new = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data.

# %%
# Make predictions on the testing data
y_pred = nn_new.predict(X_test_scaled).round().astype("int32")
# Out:
# 13/13 [==============================] - 0s 1ms/step

# %% [markdown]
# ### Step 3: Create a DataFrame to compare the predictions with the actual values.

# %%
# Create a DataFrame to compare the predictions with the actual values
compare_df = pd.DataFrame({
    "Predicted": y_pred.ravel(),
    "Actual": y_test.ravel()
})

# %% [markdown]
# ### Step 4: Display a sample of the DataFrame you created in step 3.

# %%
# Display sample data
compare_df[:10]
# Out:
#    Predicted  Actual
# 0          5       5
# 1          5       6
# 2          6       6
# 3          5       6
# 4          7       6
# 5          6       6
# 6          6       6
# 7          4       5
# 8          5       5
# 9          5       5
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Predicted'].plot(kind='hist', bins=20, title='Predicted')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Actual'].plot(kind='hist', bins=20, title='Actual')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='Predicted', y='Actual', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['Predicted'].plot(kind='line', figsize=(8, 4), title='Predicted')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4['Actual'].plot(kind='line', figsize=(8, 4), title='Actual')
# plt.gca().spines[['top', 'right']].set_visible(False)
